# %%
import cv2 as cv

# %%
cat=cv.imread('/Users/lixuecheng/Downloads/OpenCV/代码+资料/第2-7章notebook课件/图像操作/cat.jpg')
dog=cv.imread('/Users/lixuecheng/Downloads/OpenCV/代码+资料/第2-7章notebook课件/图像操作/dog.jpg')

# %%
cat2=cat+10
cat2[:5,:,0]
# Out:
# array([[152, 156, 161, ..., 166, 165, 164],
#        [117, 122, 127, ..., 165, 164, 163],
#        [118, 122, 128, ..., 164, 163, 162],
#        [149, 153, 158, ..., 166, 165, 164],
#        [163, 168, 173, ..., 170, 169, 168]], dtype=uint8)

# %%
cat[:5,:,0]
# Out:
# array([[142, 146, 151, ..., 156, 155, 154],
#        [107, 112, 117, ..., 155, 154, 153],
#        [108, 112, 118, ..., 154, 153, 152],
#        [139, 143, 148, ..., 156, 155, 154],
#        [153, 158, 163, ..., 160, 159, 158]], dtype=uint8)

# %%
img_merge=(cat2+cat)[:5,:,0]

# %%
img_merge
# Out:
# array([[ 38,  46,  56, ...,  66,  64,  62],
#        [224, 234, 244, ...,  64,  62,  60],
#        [226, 234, 246, ...,  62,  60,  58],
#        [ 32,  40,  50, ...,  66,  64,  62],
#        [ 60,  70,  80, ...,  74,  72,  70]], dtype=uint8)

# %%
cat.shape
# Out:
# (414, 500, 3)

# %%
dog=cv.resize(dog,(500,414))
dog.shape
# Out:
# (414, 500, 3)

# %%
import matplotlib.pyplot as plt
plt.figure(dpi=120,figsize=(6,6))
#0.6，0.4分别代表的是在图片中占据的比例
img_sum=cv.addWeighted(cat,0.6,dog,0.4,0)
plt.title("result")
plt.imshow(img_sum)
