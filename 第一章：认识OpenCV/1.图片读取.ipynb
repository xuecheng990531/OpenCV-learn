# %%
import cv2 as cv
import matplotlib.pyplot as plt
import imutils

# %%
#创建展示图像函数
def show(img):
    plt.imshow(img)
    plt.show()

# %%
im=cv.imread("/Users/lixuecheng/Downloads/OpenCV/代码+资料/第2-7章notebook课件/图像操作/lena.png")

# %%
plt.figure(dpi=120)
plt.subplot(121),plt.imshow(im)
plt.subplot(122),plt.imshow(imutils.opencv2matplotlib(im))
# Out:
# (<AxesSubplot:>, <matplotlib.image.AxesImage at 0x11fd24880>)
