# %%
#随着光照的变换，一个物体产生的投影也不尽相同。利用透视中心，像点，目标点三个条件，

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import imutils 
import numpy as np

# %%
img=cv.imread('/Users/lixuecheng/Downloads/OpenCV/代码+资料/第2-7章notebook课件/图像操作/cat.jpg')
rows,cols=img.shape[:2]

# %%
#创建变换矩阵
pts1=np.float32([[56,65],[368,52],[28,37],[289,290]])
pts2=np.float32([[100,145],[300,100],[80,290],[310,300]])

# %%
M=cv.getPerspectiveTransform(pts1,pts2)

# %%
dst=cv.warpPerspective(img,M,(cols,rows))

# %%
plt.imshow(imutils.opencv2matplotlib(dst))
